# %% [markdown]
# # Matrix Multiplication & Results of Test Run

# %%
import numpy as np
import time

def cpu_stress_matrix(size=1000, iterations=10): #scalable through augmenting size
    A = np.random.rand(size, size)
    B = np.random.rand(size, size)

    for _ in range(iterations):
        start = time.time()
        C = np.dot(A, B)
        duration = time.time() - start
        print(f"Multiplication took {duration:.2f} seconds")

# %%
# call the function from above to test
start = time.time()
cpu_stress_matrix(size=1000, iterations=20)
end = time.time()
print(f"\n-----MEASURED Workload runtime: {end - start:.4f} seconds")

# augment iterations for long duration/ same load
# use size to increase RAM and CPU usage, can stress memory and cache
# Out:
# Multiplication took 0.03 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.00 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
#
# -----MEASURED Workload runtime: 0.3059 seconds

# %% [markdown]
# Available Gear
# - CPU AMD Ryzen 9 5900X
# - GPU NVIDIA GeForce RTX 2060
# - 32 GB RAM

# %% [markdown]
# Results: MATRIX size=2000, iterations=10 - 12.10.2025
# | Measurement           | CarbonTracker         |    CodeCarbon                     |    Time Tracking only (cell above)                     |
# |------------------|---------------|------------------------------|------------------------------|
# | Duration     | 0.4627 s     | 0.4583 s    | 0.4588    |
# | Energy        | 0.00001009 kWh (CPU only?)          | 0.000166 kWh (CPU/GPU/RAM)       | x    |
# | CO2eq         | 0.00111834 g   | ?            | x    |
#
# Results: MATRIX size=10000, iterations=20 - 12.10.2025
# | Measurement           | CarbonTracker         |    CodeCarbon                     |    Time Tracking only (cell above)                     |
# |------------------|---------------|------------------------------|------------------------------|
# | Duration     | 133.8226, 0:02:14     | 133.7430 s    | 132.9774 s    |
# | Energy        | 0.00349766 kWh (CPU only?)          | 0.048099 kWh (CPU/GPU/RAM)       | x    |
# | CO2eq         | 1.68237620 g   | ?            | x    |
#
# "CodeCarbon uses RAPL for measuring the energy consumed by the CPU and RAM [...] CodeCarbon also presents the the total energy consumed, which corresponds to the sum of the energy consumption from the CPU, GPU and RA"
# *Source: Energy Efficiency of Training Neural Network Architectures: An Empricial Study (Yinlena Xu, Silverio Martinez-Fernandez, Matias Martinez, and Xavier Franch) https://www.semanticscholar.org/reader/1d9338c23dce3abfb3e95fccc9a234e861d251d9*
#
# "Platforms such as Hugging Face encourage researchers to report CO2 emissions and recommend tools like CodeCarbon or MLCO2"
# *Source: Estimating Deep Learning energy consumption based on model architecture and training environment (Santiago del Rey, Luís Cruz, Xavier Franch, Silverio Martínez-Fernández) https://www.semanticscholar.org/reader/e87d8fe2f7475f4a9539fd84ba3aa6d7adf7cd46*

# %% [markdown]
# # CarbonTracker

# %%
# !{sys.executable} -m pip install carbontracker

# %%
# CARBONTRACKER https://github.com/saintslab/carbontracker
# pip install carbontracker or directly in the environment of notebook: !{sys.executable} -m pip install carbontracker

from carbontracker.tracker import CarbonTracker
import time

tracker = CarbonTracker(epochs=1, decimal_precision=8)

# Training loop.
for epoch in range(1):
    tracker.epoch_start()

    #### MY CODE ####
    start = time.time()
    cpu_stress_matrix(size=1000, iterations=20)
    end = time.time()
    print(f"\n-----MEASURED Workload runtime: {end - start:.4f} seconds")
    #### END MY CODE ####

    tracker.epoch_end()

# Optional: Add a stop in case of early termination before all monitor_epochs has
# been monitored to ensure that actual consumption is reported.
tracker.stop()
# Out:
# CarbonTracker: INFO - Detected CPU: AMD Ryzen 9 5900X 12-Core Processor
# CarbonTracker: WARNING - No matching TDP found for CPU: AMD Ryzen 9 5900X 12-Core Processor. Using average TDP of 35.61W at 50% utilization as fallback.
# CarbonTracker: The following components were found: GPU with device(s) NVIDIA GeForce RTX 2060. CPU with device(s) AMD Ryzen 9 5900X 12-Core Processor.
# Multiplication took 0.01 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 110.81243 gCO2/kWh.
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
#
# -----MEASURED Workload runtime: 0.2594 seconds
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 110.81243 gCO2/kWh.
# CarbonTracker: Live carbon intensity could not be fetched at detected location: Vienna, Vienna, AT. Defaulted to average carbon intensity for AT in 2023 of 110.81 gCO2/kWh. at detected location: Vienna, Vienna, AT.
# CarbonTracker:
# Predicted consumption for 1 epoch(s):
# 	Time:	0:00:00
# 	Energy:	0.00000572 kWh
# 	CO2eq:	0.00063422 g
# 	This is equivalent to:
# 	0.00000590 km travelled by car
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 110.81243 gCO2/kWh.
# CarbonTracker: Average carbon intensity during training was 110.81 gCO2/kWh at detected location: Vienna, Vienna, AT.
# CarbonTracker:
# Actual consumption for 0 epoch(s):
# 	Time:	0:00:00
# 	Energy:	0.00000572 kWh
# 	CO2eq:	0.00063422 g
# 	This is equivalent to:
# 	0.00000590 km travelled by car
# CarbonTracker: Finished monitoring.

# %% [markdown]
# # CodeCarbon

# %%
# !{sys.executable} -m pip install codecarbon
# Out:
# Collecting codecarbon
#   Using cached codecarbon-3.0.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: arrow in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (1.2.3)
# Requirement already satisfied: click in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (8.1.7)
# Collecting fief-client[cli] (from codecarbon)
#   Using cached fief_client-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (2.2.2)
# Requirement already satisfied: prometheus_client in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (0.14.1)
# Requirement already satisfied: psutil>=6.0.0 in c:\users\elisa\appdata\roaming\python\python312\site-packages (from codecarbon) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (2.8.2)
# Requirement already satisfied: nvidia-ml-py in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (13.580.82)
# Collecting rapidfuzz (from codecarbon)
#   Using cached rapidfuzz-3.14.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (2.32.3)
# Collecting questionary (from codecarbon)
#   Using cached questionary-2.1.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: rich in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (13.7.1)
# Requirement already satisfied: typer in c:\users\elisa\anaconda3\lib\site-packages (from codecarbon) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\elisa\appdata\roaming\python\python312\site-packages (from arrow->codecarbon) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\elisa\appdata\roaming\python\python312\site-packages (from click->codecarbon) (0.4.6)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in c:\users\elisa\anaconda3\lib\site-packages (from fief-client[cli]->codecarbon) (0.27.0)
# Collecting jwcrypto<2.0.0,>=1.4 (from fief-client[cli]->codecarbon)
#   Using cached jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting yaspin (from fief-client[cli]->codecarbon)
#   Using cached yaspin-3.3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\elisa\anaconda3\lib\site-packages (from pandas->codecarbon) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elisa\anaconda3\lib\site-packages (from pandas->codecarbon) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elisa\anaconda3\lib\site-packages (from pandas->codecarbon) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\elisa\anaconda3\lib\site-packages (from pydantic->codecarbon) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\elisa\anaconda3\lib\site-packages (from pydantic->codecarbon) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\elisa\anaconda3\lib\site-packages (from pydantic->codecarbon) (4.11.0)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in c:\users\elisa\appdata\roaming\python\python312\site-packages (from questionary->codecarbon) (3.0.51)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elisa\anaconda3\lib\site-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elisa\anaconda3\lib\site-packages (from requests->codecarbon) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elisa\anaconda3\lib\site-packages (from requests->codecarbon) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elisa\anaconda3\lib\site-packages (from requests->codecarbon) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\elisa\anaconda3\lib\site-packages (from rich->codecarbon) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\elisa\appdata\roaming\python\python312\site-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: anyio in c:\users\elisa\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\elisa\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\elisa\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\elisa\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in c:\users\elisa\anaconda3\lib\site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\elisa\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.0)
# Requirement already satisfied: wcwidth in c:\users\elisa\appdata\roaming\python\python312\site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\elisa\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Collecting termcolor<4.0,>=3.1 (from yaspin->fief-client[cli]->codecarbon)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\elisa\anaconda3\lib\site-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\elisa\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.21)
# Using cached codecarbon-3.0.7-py3-none-any.whl (278 kB)
# Using cached questionary-2.1.1-py3-none-any.whl (36 kB)
# Using cached rapidfuzz-3.14.1-cp312-cp312-win_amd64.whl (1.5 MB)
# Using cached jwcrypto-1.5.6-py3-none-any.whl (92 kB)
# Using cached fief_client-0.20.0-py3-none-any.whl (20 kB)
# Using cached yaspin-3.3.0-py3-none-any.whl (21 kB)
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: termcolor, rapidfuzz, yaspin, questionary, jwcrypto, fief-client, codecarbon
# Successfully installed codecarbon-3.0.7 fief-client-0.20.0 jwcrypto-1.5.6 questionary-2.1.1 rapidfuzz-3.14.1 termcolor-3.1.0 yaspin-3.3.0

# %%
# CODECARBON https://mlco2.github.io/codecarbon/
# pip install codecarbon or directly in environment of notebook !{sys.executable} -m pip install codecarbon

from codecarbon import EmissionsTracker

tracker = EmissionsTracker()
tracker.start()
try:
     # Compute intensive code goes here
     start = time.time()
     cpu_stress_matrix(size=1000, iterations=20)
     end = time.time()
     print(f"\n-----MEASURED Workload runtime: {end - start:.4f} seconds")
finally:
     tracker.stop()
# Out:
# [codecarbon WARNING @ 20:49:57] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:49:57] [setup] RAM Tracking...
# [codecarbon INFO @ 20:49:57] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:49:59] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon INFO @ 20:49:59] CPU Model on constant consumption mode: AMD Ryzen 9 5900X 12-Core Processor
# [codecarbon WARNING @ 20:49:59] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 20:49:59] [setup] GPU Tracking...
# [codecarbon INFO @ 20:49:59] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:49:59] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: pynvml
#
# [codecarbon INFO @ 20:49:59] >>> Tracker's metadata:
# [codecarbon INFO @ 20:49:59]   Platform system: Windows-10-10.0.19045-SP0
# [codecarbon INFO @ 20:49:59]   Python version: 3.12.7
# [codecarbon INFO @ 20:49:59]   CodeCarbon version: 3.0.7
# [codecarbon INFO @ 20:49:59]   Available RAM : 31.927 GB
# [codecarbon INFO @ 20:49:59]   CPU count: 24 thread(s) in 24 physical CPU(s)
# [codecarbon INFO @ 20:49:59]   CPU model: AMD Ryzen 9 5900X 12-Core Processor
# [codecarbon INFO @ 20:49:59]   GPU count: 1
# [codecarbon INFO @ 20:49:59]   GPU model: 1 x NVIDIA GeForce RTX 2060
# [codecarbon INFO @ 20:50:02] Emissions data (if any) will be saved to file c:\Users\elisa\OneDrive\Dokumente\VS_Studio_Project\Multilingual_IE_Seismic\emissions.csv
# Multiplication took 0.00 seconds
# Multiplication took 0.03 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.00 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.00 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.00 seconds
# Multiplication took 0.02 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# [codecarbon INFO @ 20:50:02] Energy consumed for RAM : 0.000001 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 20:50:02] Delta energy consumed for CPU with constant : 0.000082 kWh, power : 1260.0 W
# [codecarbon INFO @ 20:50:02] Energy consumed for All CPU : 0.000082 kWh
# [codecarbon INFO @ 20:50:02] Energy consumed for all GPUs : 0.000002 kWh. Total GPU Power : 27.29853507877278 W
# [codecarbon INFO @ 20:50:02] 0.000086 kWh of electricity used since the beginning.
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
# Multiplication took 0.01 seconds
#
# -----MEASURED Workload runtime: 0.2367 seconds
